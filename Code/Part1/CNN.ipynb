# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os,glob
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
import ast
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras.layers import Concatenate, Dense, Input, concatenate,Dropout,LeakyReLU
from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout, Input,Conv1D, GlobalMaxPooling1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import one_hot
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Flatten
from keras.models import Model
#import warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# df=pd.read_csv('articles.csv')

df=pd.read_csv('drive/MyDrive/Deep_Learning/guardian_articles.csv')
# dropping the rows having NaN values
df = df.dropna()

# %%
df
# Out:
#                                                article_id     sectionName  \
# 0       us-news/2016/jan/31/iowa-caucus-underdog-candi...         US news
# 1       us-news/2016/jan/31/iowa-caucus-worlds-most-pa...         US news
# 2       world/2016/jan/31/tanzania-britsh-helicopter-p...      World news
# 3       football/2016/jan/31/late-winner-gets-usa-off-...        Football
# 4       football/2016/jan/31/blackburn-paul-lambert-ox...        Football
# ...                                                   ...             ...
# 149834  world/2022/jun/21/marble-head-of-hercules-pull...      World news
# 149835  music/2022/jun/22/i-got-sick-of-talking-about-...           Music
# 149836  australia-news/2022/jun/22/the-small-town-with...  Australia news
# 149837  australia-news/2022/jun/22/power-to-ban-citize...  Australia news
# 149838  australia-news/2022/jun/22/liberal-mps-say-pet...  Australia news
#
#                                                  webTitle  \
# 0       Iowa underdogs put on brave faces despite all ...
# 1       Iowa caucus: hologram eagle and Jesus star on ...
# 2       British pilot in Tanzania 'manoeuvred ​to save...
# 3       USA 3-2 Iceland | International friendly match...
# 4       Reinvigorated Paul Lambert reflects after impr...
# ...                                                   ...
# 149834  Marble head of Hercules pulled up from Roman s...
# 149835  ‘I got sick of talking about myself’: Spacey J...
# 149836  The small town with a big potato that inspired...
# 149837  Power to ban citizens from re-entering Austral...
# 149838  Liberal MPs say Peter Dutton should let party ...
#
#                                                    webUrl  \
# 0       https://www.theguardian.com/us-news/2016/jan/3...
# 1       https://www.theguardian.com/us-news/2016/jan/3...
# 2       https://www.theguardian.com/world/2016/jan/31/...
# 3       https://www.theguardian.com/football/2016/jan/...
# 4       https://www.theguardian.com/football/2016/jan/...
# ...                                                   ...
# 149834  https://www.theguardian.com/world/2022/jun/21/...
# 149835  https://www.theguardian.com/music/2022/jun/22/...
# 149836  https://www.theguardian.com/australia-news/202...
# 149837  https://www.theguardian.com/australia-news/202...
# 149838  https://www.theguardian.com/australia-news/202...
#
#                                               bodyContent  \
# 0       As polling day looms and the cameras turn only...
# 1       In Des Moines on Sunday, the Guardian was give...
# 2       A British pilot who was shot dead by an elepha...
# 3       USA took a step toward shaking off the ghosts ...
# 4       The clean-shaven, spectacle free and suspiciou...
# ...                                                   ...
# 149834  For archaeologists, it’s the underwater find t...
# 149835  From under a mop of curls, Caleb Harper – Spac...
# 149836  Robertson is a small, pretty town perched on t...
# 149837  A high court decision striking down the home a...
# 149838  Liberal MPs are urging Peter Dutton to let the...
#
#           webPublicationDate      id
# 0       2016-01-31T23:53:37Z       1
# 1       2016-01-31T23:46:28Z       2
# 2       2016-01-31T23:43:48Z       3
# 3       2016-01-31T23:30:49Z       4
# 4       2016-01-31T22:30:10Z       5
# ...                      ...     ...
# 149834  2022-06-21T17:31:32Z  149835
# 149835  2022-06-21T17:30:09Z  149836
# 149836  2022-06-21T17:30:09Z  149837
# 149837  2022-06-21T17:30:08Z  149838
# 149838  2022-06-21T17:30:08Z  149839
#
# [148731 rows x 7 columns]

# %%
df['text']=df['bodyContent']
df['sentiment']=df['sectionName']

# %%
vc = df['sentiment'].value_counts()  # get value counts of 'class' column
keep_classes = vc.index[vc >= 10000]  # get classes with counts >= 2
df = df[df['sentiment'].isin(keep_classes)]

# %%
df.columns
# Out:
# Index(['article_id', 'sectionName', 'webTitle', 'webUrl', 'bodyContent',
#        'webPublicationDate', 'id', 'text', 'sentiment'],
#       dtype='object')

# %%
Data=df['text']
Label=df['sentiment']
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
Y = le.fit_transform(Label)

# %%
df['sentiment'].value_counts()
# Out:
# World news    15475
# Opinion       11964
# Football      10722
# Sport         10266
# Name: sentiment, dtype: int64

# %%
from sklearn.utils import shuffle
data_p,label=shuffle(Data,Y)

# %%
Data
# Out:
# 2         A British pilot who was shot dead by an elepha...
# 3         USA took a step toward shaking off the ghosts ...
# 4         The clean-shaven, spectacle free and suspiciou...
# 5         Reality caught up with Kevin Nolan on Saturday...
# 6         Jürgen Klopp’s exasperation was understandable...
#                                 ...
# 149827    Multiple European countries are experiencing a...
# 149828    Emmanuel Macron has met leaders of opposition ...
# 149830    Paris police were aggressive, provocative and ...
# 149833    There was no Ben Stokes at England training on...
# 149834    For archaeologists, it’s the underwater find t...
# Name: text, Length: 48427, dtype: object

# %%
#from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout, Input
#from keras.preprocessing import sequence
voc_size=50000
onehot_repr=[one_hot(word,voc_size) for word in data_p]
max_len=500
embedding_vec_features=100
embedded_docs=pad_sequences(onehot_repr,padding='post',maxlen=max_len)

# %%
 #-----Number of features to be selected------
K=40078
#--------------------------------------------
#----Number of epochs to be run--------------
epoochs=5
#--------------------------------------------
#---Testng size------------------------------
TSize=0.10
#--------------------------------------------
#optimizer1 = tf.keras.optimizers.RMSprop()
#optimizer = tf.keras.optimizers.Adamax()
#optimizer = tf.keras.optimizers.Adagrad()
optimizer1 = tf.keras.optimizers.Adam()

# %%
# Defining model Architecture 2-------------------
from tensorflow.keras.layers import BatchNormalization
model = Sequential()
model=Sequential()
model.add(Embedding(voc_size,embedding_vec_features,input_length=max_len))
model.add(Conv1D(64, 5, activation='relu'))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(4,activation='softmax'))
model.compile(optimizer=optimizer1,
loss='sparse_categorical_crossentropy',
metrics=['accuracy']
)
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 500, 100)          5000000
#
#  conv1d (Conv1D)             (None, 496, 64)           32064
#
#  batch_normalization (BatchN  (None, 496, 64)          256
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 496, 64)           0
#
#  max_pooling1d (MaxPooling1D  (None, 248, 64)          0
#  )
#
#  flatten (Flatten)           (None, 15872)             0
#
#  dense (Dense)               (None, 4)                 63492
#
# =================================================================
# Total params: 5,095,812
# Trainable params: 5,095,684
# Non-trainable params: 128
# _________________________________________________________________

# %%
X_final=np.array(embedded_docs)
Y_final=np.array(label)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_final, Y_final,test_size=0.1, random_state=42)

# %%
 history=model.fit(X_final, Y_final, epochs=5,batch_size=128, verbose=1,validation_split=0.1)
# Out:
# Epoch 1/5
# 341/341 [==============================] - 237s 691ms/step - loss: 0.4650 - accuracy: 0.8280 - val_loss: 0.5418 - val_accuracy: 0.9568
# Epoch 2/5
# 341/341 [==============================] - 230s 672ms/step - loss: 0.0243 - accuracy: 0.9944 - val_loss: 0.1463 - val_accuracy: 0.9542
# Epoch 3/5
# 341/341 [==============================] - 226s 663ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1665 - val_accuracy: 0.9585
# Epoch 4/5
# 341/341 [==============================] - 229s 672ms/step - loss: 6.8535e-04 - accuracy: 1.0000 - val_loss: 0.1737 - val_accuracy: 0.9583
# Epoch 5/5
# 341/341 [==============================] - 238s 698ms/step - loss: 3.8979e-04 - accuracy: 1.0000 - val_loss: 0.1785 - val_accuracy: 0.9587

# %%
from keras.models import Sequential, load_model
import pickle
#saving model
model.save('CNN_word_model.h5')
pickle.dump(history, open("history.p", "wb"))
model = load_model('CNN_word_model.h5')
history = pickle.load(open("history.p", "rb"))

# %%
acc = model.evaluate(X_test,y_test,verbose=0) # verbose kept 0 to avoid way too big progress bar
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc[0],acc[1]))
# Out:
# Test set
#   Loss: 0.017
#   Accuracy: 0.995

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

# %%
plt.title('CNN Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(range(len(acc)),acc, label='train')
plt.plot(range(len(val_acc)),val_acc, label='test')
plt.legend()
plt.show()

# %%
plt.title('CNN Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(range(len(loss)),loss, label='train')
plt.plot(range(len(val_loss)),val_loss, label='test')
plt.legend()
plt.show()
