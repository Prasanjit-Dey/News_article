# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os,glob
import pandas as pd
import numpy as np
import ast
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
import tensorflow as tf
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from keras.layers import Flatten
from keras.models import Model
#import warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# df=pd.read_csv('articles.csv')

df=pd.read_csv('drive/MyDrive/Deep_Learning/guardian_articles.csv')
# dropping the rows having NaN values
df = df.dropna()

# %%
df
# Out:
#                                                article_id     sectionName  \
# 0       us-news/2016/jan/31/iowa-caucus-underdog-candi...         US news
# 1       us-news/2016/jan/31/iowa-caucus-worlds-most-pa...         US news
# 2       world/2016/jan/31/tanzania-britsh-helicopter-p...      World news
# 3       football/2016/jan/31/late-winner-gets-usa-off-...        Football
# 4       football/2016/jan/31/blackburn-paul-lambert-ox...        Football
# ...                                                   ...             ...
# 149834  world/2022/jun/21/marble-head-of-hercules-pull...      World news
# 149835  music/2022/jun/22/i-got-sick-of-talking-about-...           Music
# 149836  australia-news/2022/jun/22/the-small-town-with...  Australia news
# 149837  australia-news/2022/jun/22/power-to-ban-citize...  Australia news
# 149838  australia-news/2022/jun/22/liberal-mps-say-pet...  Australia news
#
#                                                  webTitle  \
# 0       Iowa underdogs put on brave faces despite all ...
# 1       Iowa caucus: hologram eagle and Jesus star on ...
# 2       British pilot in Tanzania 'manoeuvred ​to save...
# 3       USA 3-2 Iceland | International friendly match...
# 4       Reinvigorated Paul Lambert reflects after impr...
# ...                                                   ...
# 149834  Marble head of Hercules pulled up from Roman s...
# 149835  ‘I got sick of talking about myself’: Spacey J...
# 149836  The small town with a big potato that inspired...
# 149837  Power to ban citizens from re-entering Austral...
# 149838  Liberal MPs say Peter Dutton should let party ...
#
#                                                    webUrl  \
# 0       https://www.theguardian.com/us-news/2016/jan/3...
# 1       https://www.theguardian.com/us-news/2016/jan/3...
# 2       https://www.theguardian.com/world/2016/jan/31/...
# 3       https://www.theguardian.com/football/2016/jan/...
# 4       https://www.theguardian.com/football/2016/jan/...
# ...                                                   ...
# 149834  https://www.theguardian.com/world/2022/jun/21/...
# 149835  https://www.theguardian.com/music/2022/jun/22/...
# 149836  https://www.theguardian.com/australia-news/202...
# 149837  https://www.theguardian.com/australia-news/202...
# 149838  https://www.theguardian.com/australia-news/202...
#
#                                               bodyContent  \
# 0       As polling day looms and the cameras turn only...
# 1       In Des Moines on Sunday, the Guardian was give...
# 2       A British pilot who was shot dead by an elepha...
# 3       USA took a step toward shaking off the ghosts ...
# 4       The clean-shaven, spectacle free and suspiciou...
# ...                                                   ...
# 149834  For archaeologists, it’s the underwater find t...
# 149835  From under a mop of curls, Caleb Harper – Spac...
# 149836  Robertson is a small, pretty town perched on t...
# 149837  A high court decision striking down the home a...
# 149838  Liberal MPs are urging Peter Dutton to let the...
#
#           webPublicationDate      id
# 0       2016-01-31T23:53:37Z       1
# 1       2016-01-31T23:46:28Z       2
# 2       2016-01-31T23:43:48Z       3
# 3       2016-01-31T23:30:49Z       4
# 4       2016-01-31T22:30:10Z       5
# ...                      ...     ...
# 149834  2022-06-21T17:31:32Z  149835
# 149835  2022-06-21T17:30:09Z  149836
# 149836  2022-06-21T17:30:09Z  149837
# 149837  2022-06-21T17:30:08Z  149838
# 149838  2022-06-21T17:30:08Z  149839
#
# [148731 rows x 7 columns]

# %%
df['text']=df['bodyContent']
df['sentiment']=df['sectionName']

# %%
vc = df['sentiment'].value_counts()  # get value counts of 'class' column
keep_classes = vc.index[vc >= 10000]  # get classes with counts >= 2
df = df[df['sentiment'].isin(keep_classes)]

# %%
df=df[:5000]

# %%
train_size = int(len(df) * 0.8)
train_data = df['text'][:train_size]
train_labels = df['sentiment'][:train_size]
test_data = df['text'][train_size:]
test_labels = df['sentiment'][train_size:]

# %%
# Fit and transform the training data with the TF-IDF vectorizer
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(train_data)

# %%
# Transform the test data using the fitted vectorizer
X_test = vectorizer.transform(test_data)

# %%
# Fit the SVM model on the training data
from sklearn import svm
clf = svm.SVC()
history=clf.fit(X_train, train_labels)

# %%
# Evaluate the model on the test data
acc = clf.score(X_test, test_labels)
print("Accuracy:", acc)
# Out:
# Accuracy: 0.932

# %%
from keras.models import Sequential, load_model
import pickle
# Save the trained model
filename = 'svm_model.sav'
pickle.dump(clf, open(filename, 'wb'))
# Load the saved model
loaded_model = pickle.load(open(filename, 'rb'))
y_pred = loaded_model.predict(X_test)
print(y_pred)
# Out:
# ['World news' 'Opinion' 'Opinion' 'Sport' 'Sport' 'Opinion' 'World news'
#  'Opinion' 'World news' 'World news' 'World news' 'World news'
#  'World news' 'Sport' 'Opinion' 'Football' 'Opinion' 'Football' 'Football'
#  'Football' 'World news' 'Opinion' 'Opinion' 'World news' 'Sport'
#  'Football' 'Football' 'Opinion' 'Football' 'Football' 'World news'
#  'Football' 'Sport' 'World news' 'Opinion' 'World news' 'Football'
#  'Football' 'Football' 'Opinion' 'World news' 'World news' 'World news'
#  'Opinion' 'Opinion' 'Sport' 'World news' 'Opinion' 'World news' 'Opinion'
#  'Opinion' 'World news' 'Sport' 'Sport' 'Football' 'Football' 'Sport'
#  'Sport' 'Sport' 'Football' 'World news' 'Sport' 'Football' 'Sport'
#  'World news' 'Football' 'Football' 'Sport' 'World news' 'Opinion'
#  'World news' 'World news' 'World news' 'Opinion' 'World news' 'Sport'
#  'Sport' 'Sport' 'Opinion' 'World news' 'Football' 'World news'
#  'World news' 'Football' 'Football' 'Football' 'Opinion' 'Opinion'
#  'Football' 'Opinion' 'Football' 'World news' 'World news' 'Sport'
#  'World news' 'Opinion' 'World news' 'Sport' 'World news' 'World news'
#  'Opinion' 'Football' 'World news' 'Opinion' 'Football' 'World news'
#  'Sport' 'World news' 'Opinion' 'World news' 'Opinion' 'Opinion'
#  'World news' 'World news' 'Opinion' 'World news' 'Opinion' 'Sport'
#  'Sport' 'World news' 'World news' 'Opinion' 'Football' 'Sport' 'Sport'
#  'Opinion' 'World news' 'Football' 'Opinion' 'World news' 'World news'
#  'World news' 'Opinion' 'Opinion' 'World news' 'Opinion' 'Sport' 'Opinion'
#  'Sport' 'World news' 'World news' 'Sport' 'World news' 'Football'
#  'Football' 'Football' 'Opinion' 'Sport' 'Sport' 'Sport' 'Opinion'
#  'Opinion' 'World news' 'Football' 'Opinion' 'Football' 'Sport' 'Football'
#  'Opinion' 'World news' 'Sport' 'Opinion' 'Opinion' 'World news'
#  'World news' 'Opinion' 'World news' 'Opinion' 'Football' 'Sport'
#  'World news' 'World news' 'Sport' 'Sport' 'Sport' 'Football' 'World news'
#  'World news' 'Sport' 'Football' 'World news' 'World news' 'World news'
#  'World news' 'World news' 'Sport' 'World news' 'Opinion' 'Opinion'
#  'Opinion' 'World news' 'Opinion' 'Football' 'World news' 'World news'
